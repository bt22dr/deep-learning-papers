# %%
# %matplotlib inline

import sys
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

print(tf.__version__)
# Out:
# 1.8.0

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
from tensorflow.examples.tutorials.mnist import input_data

mnist = tf.contrib.learn.datasets.load_dataset("mnist")
# Out:
# WARNING:tensorflow:From <ipython-input-3-6e14d16dc188>:3: load_dataset (from tensorflow.contrib.learn.python.learn.datasets) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data.
# WARNING:tensorflow:From /home/jysong/anaconda3/envs/tf18/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/__init__.py:80: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/jysong/anaconda3/envs/tf18/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:300: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/jysong/anaconda3/envs/tf18/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/jysong/anaconda3/envs/tf18/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST-data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/jysong/anaconda3/envs/tf18/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST-data/train-labels-idx1-ubyte.gz
# Extracting MNIST-data/t10k-images-idx3-ubyte.gz
# Extracting MNIST-data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/jysong/anaconda3/envs/tf18/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None, real_dim), name='input_real') 
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    
    return inputs_real, inputs_z

# %%
def generator(z, out_dim, n_units=128, reuse=False):
    with tf.variable_scope('generator', reuse=reuse):
        alpha=0.01
        
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        
        # Hidden layer
        h2 = tf.layers.dense(h1, n_units, activation=None)
        
        # Leaky ReLU
        h2 = tf.maximum(alpha * h2, h2)
        
        # Logits and tanh output
        out = tf.layers.dense(h2, out_dim, activation=tf.nn.sigmoid)
        
        return out

def discriminator(x, n_units=128, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        alpha=0.01
        
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation=None)
        
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
                
        # Hidden layer
        h2 = tf.layers.dense(h1, n_units, activation=None)
        
        # Leaky ReLU
        h2 = tf.maximum(alpha * h2, h2)
        
        # Dropout
        h2 = tf.nn.dropout(h2, 0.5)
        
        logits = tf.layers.dense(h2, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %%
# Size of input image to discriminator
input_size = 28*28
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 256
d_hidden_size = 256

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z = model_inputs(input_size, z_size)

# Build the model
g_model = generator(input_z, input_size, n_units=g_hidden_size)
# g_model is the generator output

d_model_real, d_logits_real = discriminator(input_real, n_units=d_hidden_size)
d_model_fake, d_logits_fake = discriminator(g_model, reuse=True, n_units=d_hidden_size)

# %%
# Calculate losses
'''
eps = sys.float_info.epsilon
g_loss = tf.reduce_mean(-tf.log(d_model_fake + eps))
d_loss = tf.reduce_mean(-tf.log(d_model_real + eps) - tf.log(1 - d_model_fake + eps))
'''

d_loss = -(tf.reduce_mean(d_logits_real) - tf.reduce_mean(d_logits_fake))
g_loss = -tf.reduce_mean(d_logits_fake)

# %%
# Optimizers
learning_rate = 0.0001

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

clipping = [var.assign(tf.clip_by_value(var, -0.01, 0.01)) for var in d_vars]

d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %%
batch_size = 64
epochs = 100
samples = []
losses = []
# Only save generator variables
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    gen_iterations = 0
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            
            # Run optimizers
            if gen_iterations < 25 or gen_iterations % 500 == 0:
                ncritic = 100
            else:
                ncritic = 5
                
            for _ in range(ncritic):
                batch = mnist.train.next_batch(batch_size)
            
                # Get images, reshape and rescale to pass to D
                #batch_images = batch_images*2 - 1
                batch_images = batch[0].reshape((batch_size, 784))

                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))

                sess.run(clipping)
                sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            sess.run(g_train_opt, feed_dict={input_z: batch_z})
            gen_iterations += 1
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        #losses.append((np.abs(train_loss_d), np.abs(train_loss_g)))
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/100... Discriminator Loss: -0.4589... Generator Loss: 0.1570
# Epoch 2/100... Discriminator Loss: -0.4824... Generator Loss: 0.1275
# Epoch 3/100... Discriminator Loss: -0.5827... Generator Loss: 0.1967
# Epoch 4/100... Discriminator Loss: -0.4904... Generator Loss: 0.1634
# Epoch 5/100... Discriminator Loss: -0.3635... Generator Loss: 0.1095
# Epoch 6/100... Discriminator Loss: -0.3664... Generator Loss: 0.1114
# Epoch 7/100... Discriminator Loss: -0.4068... Generator Loss: 0.1600
# Epoch 8/100... Discriminator Loss: -0.2979... Generator Loss: 0.1167
# Epoch 9/100... Discriminator Loss: -0.2362... Generator Loss: 0.1532
# Epoch 10/100... Discriminator Loss: -0.3066... Generator Loss: 0.0180
# Epoch 11/100... Discriminator Loss: -0.2770... Generator Loss: 0.0787
# Epoch 12/100... Discriminator Loss: -0.2432... Generator Loss: 0.0402
# Epoch 13/100... Discriminator Loss: -0.1979... Generator Loss: -0.1014
# Epoch 14/100... Discriminator Loss: -0.2297... Generator Loss: -0.0386
# Epoch 15/100... Discriminator Loss: -0.2276... Generator Loss: -0.0709
# Epoch 16/100... Discriminator Loss: -0.2295... Generator Loss: 0.0479
# Epoch 17/100... Discriminator Loss: -0.2181... Generator Loss: -0.0359
# Epoch 18/100... Discriminator Loss: -0.1659... Generator Loss: -0.0381
# Epoch 19/100... Discriminator Loss: -0.1990... Generator Loss: -0.0426
# Epoch 20/100... Discriminator Loss: -0.1718... Generator Loss: 0.0313
# Epoch 21/100... Discriminator Loss: -0.1683... Generator Loss: -0.0101
# Epoch 22/100... Discriminator Loss: -0.1489... Generator Loss: -0.0153
# Epoch 23/100... Discriminator Loss: -0.1670... Generator Loss: -0.0445
# Epoch 24/100... Discriminator Loss: -0.1813... Generator Loss: -0.0197
# Epoch 25/100... Discriminator Loss: -0.1468... Generator Loss: 0.0016
# Epoch 26/100... Discriminator Loss: -0.1361... Generator Loss: -0.0327
# Epoch 27/100... Discriminator Loss: -0.1362... Generator Loss: -0.0356
# Epoch 28/100... Discriminator Loss: -0.0993... Generator Loss: -0.0058
# Epoch 29/100... Discriminator Loss: -0.1556... Generator Loss: -0.0393
# Epoch 30/100... Discriminator Loss: -0.1290... Generator Loss: -0.0483
# Epoch 31/100... Discriminator Loss: -0.1287... Generator Loss: -0.0535
# Epoch 32/100... Discriminator Loss: -0.0899... Generator Loss: -0.0518
# Epoch 33/100... Discriminator Loss: -0.1363... Generator Loss: -0.0521
# Epoch 34/100... Discriminator Loss: -0.1051... Generator Loss: -0.0453
# Epoch 35/100... Discriminator Loss: -0.0712... Generator Loss: -0.0524
# Epoch 36/100... Discriminator Loss: -0.0940... Generator Loss: -0.0624
# Epoch 37/100... Discriminator Loss: -0.1040... Generator Loss: -0.0569
# Epoch 38/100... Discriminator Loss: -0.1020... Generator Loss: -0.0369
# Epoch 39/100... Discriminator Loss: -0.1255... Generator Loss: -0.0479
# Epoch 40/100... Discriminator Loss: -0.0979... Generator Loss: -0.0429
# Epoch 41/100... Discriminator Loss: -0.0870... Generator Loss: -0.0338
# Epoch 42/100... Discriminator Loss: -0.0773... Generator Loss: -0.0243
# Epoch 43/100... Discriminator Loss: -0.0975... Generator Loss: -0.0514
# Epoch 44/100... Discriminator Loss: -0.1080... Generator Loss: -0.0297
# Epoch 45/100... Discriminator Loss: -0.0708... Generator Loss: -0.0603
# Epoch 46/100... Discriminator Loss: -0.0968... Generator Loss: -0.0427
# Epoch 47/100... Discriminator Loss: -0.0873... Generator Loss: -0.0524
# Epoch 48/100... Discriminator Loss: -0.0760... Generator Loss: -0.0554
# Epoch 49/100... Discriminator Loss: -0.1058... Generator Loss: -0.0350
# Epoch 50/100... Discriminator Loss: -0.0798... Generator Loss: -0.0164
# Epoch 51/100... Discriminator Loss: -0.0881... Generator Loss: -0.0243
# Epoch 52/100... Discriminator Loss: -0.0709... Generator Loss: -0.0496
# Epoch 53/100... Discriminator Loss: -0.0593... Generator Loss: -0.0363
# Epoch 54/100... Discriminator Loss: -0.0731... Generator Loss: -0.0338
# Epoch 55/100... Discriminator Loss: -0.0745... Generator Loss: -0.0594
# Epoch 56/100... Discriminator Loss: -0.0938... Generator Loss: -0.0442
# Epoch 57/100... Discriminator Loss: -0.0627... Generator Loss: -0.0545
# Epoch 58/100... Discriminator Loss: -0.0805... Generator Loss: -0.0658
# Epoch 59/100... Discriminator Loss: -0.0618... Generator Loss: -0.0707
# Epoch 60/100... Discriminator Loss: -0.0505... Generator Loss: -0.0571
# Epoch 61/100... Discriminator Loss: -0.0686... Generator Loss: -0.0225
# Epoch 62/100... Discriminator Loss: -0.0795... Generator Loss: -0.0809
# Epoch 63/100... Discriminator Loss: -0.0954... Generator Loss: -0.0507
# Epoch 64/100... Discriminator Loss: -0.0674... Generator Loss: -0.0448
# Epoch 65/100... Discriminator Loss: -0.0736... Generator Loss: -0.0521
# Epoch 66/100... Discriminator Loss: -0.0656... Generator Loss: -0.0644
# Epoch 67/100... Discriminator Loss: -0.0427... Generator Loss: -0.0099
# Epoch 68/100... Discriminator Loss: -0.0491... Generator Loss: -0.0699
# Epoch 69/100... Discriminator Loss: -0.0403... Generator Loss: -0.0895
# Epoch 70/100... Discriminator Loss: -0.0823... Generator Loss: -0.0691
# Epoch 71/100... Discriminator Loss: -0.0378... Generator Loss: -0.0755
# Epoch 72/100... Discriminator Loss: -0.0541... Generator Loss: -0.0592
# Epoch 73/100... Discriminator Loss: -0.0632... Generator Loss: -0.0497
# Epoch 74/100... Discriminator Loss: -0.0471... Generator Loss: -0.0439
# Epoch 75/100... Discriminator Loss: -0.0676... Generator Loss: -0.0562
# Epoch 76/100... Discriminator Loss: -0.0634... Generator Loss: -0.0757
# Epoch 77/100... Discriminator Loss: -0.0669... Generator Loss: -0.0673
# Epoch 78/100... Discriminator Loss: -0.0661... Generator Loss: -0.0853
# Epoch 79/100... Discriminator Loss: -0.0827... Generator Loss: -0.0565
# Epoch 80/100... Discriminator Loss: -0.0673... Generator Loss: -0.0252
# Epoch 81/100... Discriminator Loss: -0.0611... Generator Loss: -0.0564
# Epoch 82/100... Discriminator Loss: -0.0668... Generator Loss: -0.0639
# Epoch 83/100... Discriminator Loss: -0.0542... Generator Loss: -0.0593
# Epoch 84/100... Discriminator Loss: -0.0635... Generator Loss: -0.0388
# Epoch 85/100... Discriminator Loss: -0.0890... Generator Loss: -0.0561
# Epoch 86/100... Discriminator Loss: -0.0389... Generator Loss: -0.0373
# Epoch 87/100... Discriminator Loss: -0.0705... Generator Loss: -0.0410
# Epoch 88/100... Discriminator Loss: -0.0541... Generator Loss: -0.0343
# Epoch 89/100... Discriminator Loss: -0.0559... Generator Loss: -0.0659
# Epoch 90/100... Discriminator Loss: -0.0423... Generator Loss: -0.0499
# Epoch 91/100... Discriminator Loss: -0.0640... Generator Loss: -0.0180
# Epoch 92/100... Discriminator Loss: -0.0573... Generator Loss: -0.0249
# Epoch 93/100... Discriminator Loss: -0.0579... Generator Loss: -0.0492
# Epoch 94/100... Discriminator Loss: -0.0801... Generator Loss: -0.0228
# Epoch 95/100... Discriminator Loss: -0.0433... Generator Loss: -0.0588
# Epoch 96/100... Discriminator Loss: -0.0485... Generator Loss: -0.0577
# Epoch 97/100... Discriminator Loss: -0.0493... Generator Loss: -0.0883
# Epoch 98/100... Discriminator Loss: -0.0530... Generator Loss: -0.0364
# Epoch 99/100... Discriminator Loss: -0.0274... Generator Loss: -0.0604
# Epoch 100/100... Discriminator Loss: -0.0576... Generator Loss: -0.0343

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
