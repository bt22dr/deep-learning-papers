# %%
# %matplotlib inline

import os
import sys
import glob
import imageio
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

print(tf.__version__)
# Out:
# 1.3.0

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def model_inputs(real_dim, z_dim, class_dim):
    inputs_real = tf.placeholder(tf.float32, (None, real_dim), name='input_real') 
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    inputs_y = tf.placeholder(tf.float32, (None, class_dim), name='input_y')
    
    return inputs_real, inputs_z, inputs_y

# %%
def generator(z, y, out_dim, n_units=128, reuse=False):
    with tf.variable_scope('generator', reuse=reuse):
        alpha=0.2
        
        z = tf.concat(values=[z, y], axis=1)
        
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        
        # Hidden layer
        h2 = tf.layers.dense(h1, n_units, activation=None)
        
        # Leaky ReLU
        h2 = tf.maximum(alpha * h2, h2)
        
        # Logits and tanh output
        out = tf.layers.dense(h2, out_dim, activation=tf.nn.tanh)
        
        return out

def discriminator(x, y, n_units=128, reuse=False):
    with tf.variable_scope('discriminator', reuse=reuse):
        alpha=0.2
        x = tf.concat([x, y], axis=1)
        
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation=None)
        
        # Leaky ReLU
        h1 = tf.maximum(alpha * h1, h1)
        
        # Dropout
        h1 = tf.nn.dropout(h1, 0.8)
        
        # Hidden layer
        h2 = tf.layers.dense(h1, n_units, activation=tf.nn.relu)
        
        logits = tf.layers.dense(h2, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %%
# Size of input image to discriminator
input_size = 28*28
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 256
d_hidden_size = 256

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z, input_y = model_inputs(input_size, z_size, 10)

# Build the model
g_model = generator(input_z, input_y, input_size, n_units=g_hidden_size)
# g_model is the generator output

d_model_real, d_logits_real = discriminator(input_real, input_y, n_units=d_hidden_size)
d_model_fake, d_logits_fake = discriminator(g_model, input_y, reuse=True, n_units=d_hidden_size)

# %%
# Calculate losses
'''
d_loss_real = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                          labels=tf.ones_like(d_logits_real)))
d_loss_fake = tf.reduce_mean(
                  tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                          labels=tf.zeros_like(d_logits_real)))
d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(
             tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                     labels=tf.ones_like(d_logits_fake)))
'''

eps = sys.float_info.epsilon
g_loss = tf.reduce_mean(-tf.log(d_model_fake + eps))
d_loss = tf.reduce_mean(-tf.log(d_model_real + eps) - tf.log(1 - d_model_fake + eps))

# %%
# Optimizers
learning_rate = 0.0005

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %%
fixed_z = np.random.uniform(-1, 1, size=(100,100))
fixed_y = np.zeros((100,10))

eye = np.eye(10)
for i in range(10):
    for j in range(10):
        fixed_y[i*10+j] = eye[i]

# %%
batch_size = 100
epochs = 100
samples = []
losses = []

files = glob.glob('./images/cgan/*')
for f in files:
    os.remove(f)
os.makedirs('./images/cgan/', exist_ok=True)
        
# Only save generator variables
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            batch_labels = batch[1]
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_y: batch_labels, input_z: batch_z})
            # _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z, input_y: batch_labels})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_y: batch_labels, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z, input_y: batch_labels})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        num_samples = 16
        sample_z = np.random.uniform(-1, 1, size=(num_samples, z_size))
        y_one_hot = np.zeros((num_samples, 10))
        for i in range(16):
            y_one_hot[i, np.random.randint(10)] = 1
        gen_samples = sess.run(
                       generator(input_z, input_y, input_size, n_units=g_hidden_size, reuse=True),
                       feed_dict={input_z: sample_z, input_y: y_one_hot})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')
        
        gen_samples = sess.run(
                   generator(input_z, input_y, input_size, n_units=g_hidden_size, reuse=True),
                   feed_dict={input_z: fixed_z, input_y: fixed_y})

        if e % 5 == 0:
            rows, cols = 10, 10
            fig, axes = plt.subplots(figsize=(5,5), nrows=rows, ncols=cols, sharex=True, sharey=True)

            for i, ax_row in enumerate(axes):
                for j, ax in enumerate(ax_row):
                    _ = ax.imshow(gen_samples[i*10+j].reshape((28,28)), cmap='Greys_r')
                    ax.xaxis.set_visible(False)
                    ax.yaxis.set_visible(False)

            plt.savefig("./images/cgan/epoch_{:02}.png".format(e))

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)

# Make GIF image file
images = []
image_names = sorted(glob.glob('./images/cgan/epoch_*.png'))

for img_name in image_names:
    images.append(imageio.imread(img_name))
imageio.mimsave("./images/cgan/cgan.gif", images, fps=5)
# Out:
# Epoch 1/100... Discriminator Loss: 0.5183... Generator Loss: 3.0453
# Epoch 2/100... Discriminator Loss: 0.7526... Generator Loss: 2.7203
# Epoch 3/100... Discriminator Loss: 0.4870... Generator Loss: 2.1114
# Epoch 4/100... Discriminator Loss: 0.7795... Generator Loss: 3.0677
# Epoch 5/100... Discriminator Loss: 0.3260... Generator Loss: 3.5633
# Epoch 6/100... Discriminator Loss: 0.2567... Generator Loss: 3.7322
# Epoch 7/100... Discriminator Loss: 0.4759... Generator Loss: 2.0195
# Epoch 8/100... Discriminator Loss: 0.5645... Generator Loss: 2.5614
# Epoch 9/100... Discriminator Loss: 0.4018... Generator Loss: 2.1095
# Epoch 10/100... Discriminator Loss: 0.5060... Generator Loss: 2.6798
# Epoch 11/100... Discriminator Loss: 0.4534... Generator Loss: 2.4596
# Epoch 12/100... Discriminator Loss: 0.8763... Generator Loss: 1.7675
# Epoch 13/100... Discriminator Loss: 0.6019... Generator Loss: 2.3653
# Epoch 14/100... Discriminator Loss: 0.5934... Generator Loss: 2.1982
# Epoch 15/100... Discriminator Loss: 0.8903... Generator Loss: 2.2550
# Epoch 16/100... Discriminator Loss: 0.8143... Generator Loss: 1.6584
# Epoch 17/100... Discriminator Loss: 1.2391... Generator Loss: 1.3991
# Epoch 18/100... Discriminator Loss: 0.7149... Generator Loss: 2.2320
# Epoch 19/100... Discriminator Loss: 0.8557... Generator Loss: 1.8272
# Epoch 20/100... Discriminator Loss: 0.6379... Generator Loss: 1.8030
# Epoch 21/100... Discriminator Loss: 0.7861... Generator Loss: 1.7596
# Epoch 22/100... Discriminator Loss: 1.0166... Generator Loss: 1.5244
# Epoch 23/100... Discriminator Loss: 0.8369... Generator Loss: 1.5063
# Epoch 24/100... Discriminator Loss: 0.6974... Generator Loss: 1.8219
# Epoch 25/100... Discriminator Loss: 0.8099... Generator Loss: 1.5839
# Epoch 26/100... Discriminator Loss: 0.8504... Generator Loss: 1.4429
# Epoch 27/100... Discriminator Loss: 0.9159... Generator Loss: 1.2485
# Epoch 28/100... Discriminator Loss: 0.9375... Generator Loss: 1.6555
# Epoch 29/100... Discriminator Loss: 0.8534... Generator Loss: 1.4178
# Epoch 30/100... Discriminator Loss: 0.9790... Generator Loss: 1.4131
# Epoch 31/100... Discriminator Loss: 0.9164... Generator Loss: 1.3158
# Epoch 32/100... Discriminator Loss: 1.2292... Generator Loss: 1.3621
# Epoch 71/100... Discriminator Loss: 1.1416... Generator Loss: 0.9911
# Epoch 72/100... Discriminator Loss: 1.0674... Generator Loss: 1.0676
# Epoch 73/100... Discriminator Loss: 1.1732... Generator Loss: 1.1082
# Epoch 74/100... Discriminator Loss: 1.1875... Generator Loss: 0.9939
# Epoch 75/100... Discriminator Loss: 1.1700... Generator Loss: 1.0991
# Epoch 76/100... Discriminator Loss: 1.1138... Generator Loss: 1.1879
# Epoch 77/100... Discriminator Loss: 0.9706... Generator Loss: 1.1964
# Epoch 78/100... Discriminator Loss: 1.0258... Generator Loss: 1.1576
# Epoch 79/100... Discriminator Loss: 1.2034... Generator Loss: 0.9888
# Epoch 80/100... Discriminator Loss: 1.1764... Generator Loss: 0.9712
# Epoch 81/100... Discriminator Loss: 1.1941... Generator Loss: 1.1097
# Epoch 82/100... Discriminator Loss: 1.2978... Generator Loss: 0.9084
# Epoch 83/100... Discriminator Loss: 1.1464... Generator Loss: 1.1840
# Epoch 84/100... Discriminator Loss: 1.1657... Generator Loss: 0.9499
# Epoch 85/100... Discriminator Loss: 1.1940... Generator Loss: 0.9590
# Epoch 86/100... Discriminator Loss: 1.0837... Generator Loss: 1.1237
# Epoch 87/100... Discriminator Loss: 1.1456... Generator Loss: 1.1000
# Epoch 88/100... Discriminator Loss: 1.2600... Generator Loss: 1.0604
# Epoch 89/100... Discriminator Loss: 1.0152... Generator Loss: 1.1893
# Epoch 90/100... Discriminator Loss: 1.1196... Generator Loss: 1.1452
# Epoch 91/100... Discriminator Loss: 1.2246... Generator Loss: 0.9928
# Epoch 92/100... Discriminator Loss: 1.3788... Generator Loss: 0.8532
# Epoch 93/100... Discriminator Loss: 1.0465... Generator Loss: 1.1618
# Epoch 94/100... Discriminator Loss: 0.9843... Generator Loss: 1.1737
# Epoch 95/100... Discriminator Loss: 1.2199... Generator Loss: 1.2952
# Epoch 96/100... Discriminator Loss: 1.1512... Generator Loss: 1.0858
# Epoch 97/100... Discriminator Loss: 1.1850... Generator Loss: 1.1009
# Epoch 98/100... Discriminator Loss: 1.0609... Generator Loss: 1.1428
# Epoch 99/100... Discriminator Loss: 1.1027... Generator Loss: 1.2312
# Epoch 100/100... Discriminator Loss: 1.1463... Generator Loss: 1.0416

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
samples = []

saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    for i in range(10):
        sample_z = np.random.uniform(-1, 1, size=(10, z_size))
        y_one_hot = np.zeros((10, 10))
        y_one_hot[:, i] = 1
        
        gen_samples = sess.run(
                       generator(input_z, input_y, input_size, n_units=g_hidden_size, reuse=True),
                       feed_dict={input_z: sample_z, input_y: y_one_hot})
        samples.append(gen_samples)
        
            
rows, cols = 10, 10
fig, axes = plt.subplots(figsize=(7,7), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/generator.ckpt

# %%
from IPython.display import Image

with open('./images/cgan/cgan.gif', 'rb') as f:
    display(Image(data=f.read(), format='png'))
